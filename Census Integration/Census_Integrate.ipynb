# %%
from pycitylayers.client import Client
from pycitylayers.utils import PointGQL, PolygonGQL
import pandas as pd

import matplotlib.pyplot as plt
from shapely.geometry import Polygon, Point

# %%
client = Client().create(source='cerc')
coll = client.collection
tb=coll[9][0]
print(tb)
query_point_x,query_point_y="-73.570552324815","45.530402345761175"
query_radius=0.05
query_geometry = PointGQL().point(-73.5801499,45.4963536)


query_options = {
    # 'columns': ['index', 'built_area', 'geom', 'year_built'], 
    'nrows': 10000, 
    'skiprows': 0,
    'geometry_operation': 'distance_from_point',
    'geom_distance': query_radius,
    'geometry': query_geometry,
    'crs_epsg': 4326,
}

data_tracts = tb.query_simple( **query_options )
print("selecting {} tracts in {} m radius of point {},{}".format(len(data_tracts),round(query_radius*111100),query_point_x,query_point_y))
display(data_tracts.head())

for i in range(len(data_tracts)):
    vertex = data_tracts.iloc[i,:]["geom"]["coordinates"][0][0]
    polygon1=Polygon(vertex)
    plt.plot(*polygon1.exterior.xy)
# Out:
# Fetching Metadata. Please Wait ...
# ---------- Table:0 ----------
# Name:		census_tracts
# Description:
# Format:		CSV
#
# selecting 202 tracts in 5555 m radius of point -73.570552324815,45.530402345761175
#     CMANAME CMAPUID CMATYPE CMAUID   CTNAME      CTUID           PRNAME PRUID  \
# 0  Montréal   24462       B    462  0137.00  462013700  Quebec / Québec    24
# 1  Montréal   24462       B    462  0138.00  462013800  Quebec / Québec    24
# 2  Montréal   24462       B    462  0034.00  462003400  Quebec / Québec    24
# 3  Montréal   24462       B    462  0035.00  462003500  Quebec / Québec    24
# 4  Montréal   24462       B    462  0036.00  462003600  Quebec / Québec    24
#
#                                                 geom  index
# 0  {'type': 'MultiPolygon', 'crs': {'type': 'name...    304
# 1  {'type': 'MultiPolygon', 'crs': {'type': 'name...    305
# 2  {'type': 'MultiPolygon', 'crs': {'type': 'name...    306
# 3  {'type': 'MultiPolygon', 'crs': {'type': 'name...    307
# 4  {'type': 'MultiPolygon', 'crs': {'type': 'name...    308

# %%
data_tracts[data_tracts["CTNAME"]=="0147.00"]
# Out:
#      CMANAME CMAPUID CMATYPE CMAUID   CTNAME      CTUID           PRNAME  \
# 34  Montréal   24462       B    462  0147.00  462014700  Quebec / Québec
#
#    PRUID                                               geom  index
# 34    24  {'type': 'MultiPolygon', 'crs': {'type': 'name...    362

# %%
list(data_tracts["CTNAME"])
# Out:
# ['0137.00',
#  '0138.00',
#  '0034.00',
#  '0035.00',
#  '0036.00',
#  '0050.00',
#  '0051.00',
#  '0052.00',
#  '0053.00',
#  '0149.00',
#  '0151.00',
#  '0150.00',
#  '0054.00',
#  '0076.00',
#  '0146.00',
#  '0103.00',
#  '0104.00',
#  '0105.00',
#  '0106.00',
#  '0107.00',
#  '0108.00',
#  '0109.00',
#  '0063.00',
#  '0064.00',
#  '0029.00',
#  '0031.00',
#  '0032.00',
#  '0033.00',
#  '0110.00',
#  '0163.00',
#  '0164.00',
#  '0165.00',
#  '0126.00',
#  '0136.00',
#  '0147.00',
#  '0113.00',
#  '0114.00',
#  '0124.00',
#  '0125.00',
#  '0116.00',
#  '0117.00',
#  '0128.00',
#  '0130.00',
#  '0131.00',
#  '0132.00',
#  '0133.00',
#  '0134.00',
#  '0135.00',
#  '0148.00',
#  '0056.00',
#  '0057.00',
#  '0058.00',
#  '0059.00',
#  '0060.00',
#  '0061.00',
#  '0062.00',
#  '0166.00',
#  '0037.00',
#  '0038.00',
#  '0039.00',
#  '0042.00',
#  '0043.00',
#  '0044.00',
#  '0045.00',
#  '0046.00',
#  '0047.00',
#  '0048.00',
#  '0049.00',
#  '0074.00',
#  '0040.00',
#  '0041.00',
#  '0067.00',
#  '0068.00',
#  '0071.00',
#  '0072.00',
#  '0073.00',
#  '0075.00',
#  '0077.00',
#  '0078.00',
#  '0079.00',
#  '0080.00',
#  '0139.00',
#  '0140.00',
#  '0141.00',
#  '0142.00',
#  '0143.00',
#  '0144.00',
#  '0145.00',
#  '0152.00',
#  '0153.00',
#  '0154.00',
#  '0155.00',
#  '0156.00',
#  '0157.00',
#  '0158.00',
#  '0159.00',
#  '0160.00',
#  '0161.00',
#  '0162.00',
#  '0081.00',
#  '0082.00',
#  '0083.00',
#  '0084.00',
#  '0085.00',
#  '0086.00',
#  '0087.00',
#  '0088.00',
#  '0089.00',
#  '0212.00',
#  '0090.00',
#  '0092.00',
#  '0093.00',
#  '0095.00',
#  '0096.00',
#  '0122.00',
#  '0123.00',
#  '0351.00',
#  '0213.00',
#  '0352.00',
#  '0353.00',
#  '0354.00',
#  '0355.00',
#  '0356.00',
#  '0360.00',
#  '0361.00',
#  '0214.00',
#  '0362.00',
#  '0363.00',
#  '0364.00',
#  '0365.00',
#  '0366.00',
#  '0367.00',
#  '0207.00',
#  '0208.00',
#  '0209.00',
#  '0210.00',
#  '0211.00',
#  '0205.00',
#  '0215.00',
#  '0216.00',
#  '0217.00',
#  '0218.00',
#  '0219.00',
#  '0220.00',
#  '0221.00',
#  '0170.00',
#  '0167.00',
#  '0168.00',
#  '0169.00',
#  '0171.00',
#  '0172.00',
#  '0173.00',
#  '0174.00',
#  '0175.00',
#  '0176.00',
#  '0177.00',
#  '0178.00',
#  '0179.00',
#  '0180.00',
#  '0305.00',
#  '0181.00',
#  '0308.00',
#  '0350.00',
#  '0301.00',
#  '0302.00',
#  '0306.00',
#  '0307.00',
#  '0303.00',
#  '0311.00',
#  '0400.00',
#  '0300.00',
#  '0312.00',
#  '0304.00',
#  '0309.00',
#  '0310.00',
#  '0313.00',
#  '0314.00',
#  '0187.04',
#  '0317.03',
#  '0317.04',
#  '0097.01',
#  '0326.01',
#  '0065.01',
#  '0065.02',
#  '0066.01',
#  '0066.02',
#  '0115.01',
#  '0115.02',
#  '0070.02',
#  '0069.02',
#  '0070.01',
#  '0187.01',
#  '0127.01',
#  '0127.02',
#  '0069.01',
#  '0129.01',
#  '0129.02',
#  '0055.01',
#  '0094.01',
#  '0094.02',
#  '0055.02',
#  '0317.02']

# %%
census_data=pd.read_csv("Montreal Tracts.csv")

# %%
census_data.head()
# Out:
#      GEO UID  Census Tract name  \
# 0  4620000.0                0.0
# 1  4620001.0                1.0
# 2  4620002.0                2.0
# 3  4620003.0                3.0
# 4  4620004.0                4.0
#
#    Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 5 a.m. and 5:59 a.m.  \
# 0                                           144135.0
# 1                                              120.0
# 2                                              170.0
# 3                                              220.0
# 4                                              150.0
#
#    Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 6 a.m. and 6:59 a.m.  \
# 0                                           329230.0
# 1                                              280.0
# 2                                              280.0
# 3                                              605.0
# 4                                              310.0
#
#    Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 7 a.m. and 7:59 a.m.  \
# 0                                           528075.0
# 1                                              435.0
# 2                                              460.0
# 3                                              760.0
# 4                                              440.0
#
#    Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 8 a.m. and 8:59 a.m.  \
# 0                                           383810.0
# 1                                              190.0
# 2                                              230.0
# 3                                              460.0
# 4                                              255.0
#
#    Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 9 a.m. and 11:59 a.m.  \
# 0                                           217905.0
# 1                                              120.0
# 2                                               95.0
# 3                                              235.0
# 4                                              120.0
#
#    Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 12 p.m. and 4:59 a.m.  \
# 0                                           280660.0
# 1                                              220.0
# 2                                              415.0
# 3                                              535.0
# 4                                              310.0
#
#    Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Less than 15 minutes  \
# 0                                           341880.0
# 1                                              220.0
# 2                                              255.0
# 3                                              385.0
# 4                                              270.0
#
#    Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / 15 to 29 minutes  \
# 0                                           601245.0
# 1                                              415.0
# 2                                              525.0
# 3                                              885.0
# 4                                              455.0
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Age & Sex - Females / Total - Age groups and average age of the population - 100% data ; Females / 15 to 64 years ; Females  \
# 0                                          1379570.0
# 1                                              945.0
# 2                                             1200.0
# 3                                             2210.0
# 4                                             1115.0
#
#    Age & Sex - Females / Total - Age groups and average age of the population - 100% data ; Females / 65 years and over ; Females  \
# 0                                           380345.0
# 1                                              220.0
# 2                                              345.0
# 3                                              590.0
# 4                                              335.0
#
#    Age & Sex - Females / Average age of the population ; Females  \
# 0                                               41.6
# 1                                               43.4
# 2                                               42.2
# 3                                               43.0
# 4                                               45.1
#
#    Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 0 to 14 years ; Females  \
# 0                                               16.1
# 1                                               10.4
# 2                                               16.0
# 3                                               14.8
# 4                                               11.3
#
#    Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 15 to 64 years ; Females  \
# 0                                               65.8
# 1                                               72.7
# 2                                               65.2
# 3                                               67.4
# 4                                               68.4
#
#    Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 65 years and over ; Females  \
# 0                                               18.1
# 1                                               16.9
# 2                                               18.8
# 3                                               18.0
# 4                                               20.6
#
#    Population and dwelling counts / Population, 2016  \
# 0                                          4098927.0
# 1                                             2638.0
# 2                                             3516.0
# 3                                             6373.0
# 4                                             3176.0
#
#    Population and dwelling counts / Total private dwellings  \
# 0                                          1823281.0
# 1                                             1452.0
# 2                                             1902.0
# 3                                             3103.0
# 4                                             1704.0
#
#    Population and dwelling counts / Private dwellings occupied by usual residents  \
# 0                                          1727310.0
# 1                                             1328.0
# 2                                             1762.0
# 3                                             2937.0
# 4                                             1603.0
#
#    Population and dwelling counts / Population density per square kilometre
# 0                                              890.2
# 1                                             5710.0
# 2                                             9029.3
# 3                                             8612.2
# 4                                             7087.7
#
# [5 rows x 155 columns]

# %%
tract147=census_data[census_data["Census Tract name"]==0147.00]
tract147
# Out:
#        GEO UID  Census Tract name  \
# 162  4620147.0              147.0
#
#      Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 5 a.m. and 5:59 a.m.  \
# 162                                               15.0
#
#      Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 6 a.m. and 6:59 a.m.  \
# 162                                              120.0
#
#      Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 7 a.m. and 7:59 a.m.  \
# 162                                              435.0
#
#      Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 8 a.m. and 8:59 a.m.  \
# 162                                              475.0
#
#      Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 9 a.m. and 11:59 a.m.  \
# 162                                              250.0
#
#      Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 12 p.m. and 4:59 a.m.  \
# 162                                              185.0
#
#      Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Less than 15 minutes  \
# 162                                              180.0
#
#      Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / 15 to 29 minutes  \
# 162                                              550.0
#
#      ...  \
# 162  ...
#
#      Age & Sex - Females / Total - Age groups and average age of the population - 100% data ; Females / 15 to 64 years ; Females  \
# 162                                             1050.0
#
#      Age & Sex - Females / Total - Age groups and average age of the population - 100% data ; Females / 65 years and over ; Females  \
# 162                                              115.0
#
#      Age & Sex - Females / Average age of the population ; Females  \
# 162                                               37.1
#
#      Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 0 to 14 years ; Females  \
# 162                                               12.4
#
#      Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 15 to 64 years ; Females  \
# 162                                               78.7
#
#      Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 65 years and over ; Females  \
# 162                                                8.6
#
#      Population and dwelling counts / Population, 2016  \
# 162                                             2749.0
#
#      Population and dwelling counts / Total private dwellings  \
# 162                                             1670.0
#
#      Population and dwelling counts / Private dwellings occupied by usual residents  \
# 162                                             1519.0
#
#      Population and dwelling counts / Population density per square kilometre
# 162                                            16353.4
#
# [1 rows x 155 columns]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
#        GEO UID  Census Tract name  \
# 162  4620147.0              147.0
#
#      Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 5 a.m. and 5:59 a.m.  \
# 162                                               15.0
#
#      Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 6 a.m. and 6:59 a.m.  \
# 162                                              120.0
#
#      Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 7 a.m. and 7:59 a.m.  \
# 162                                              435.0
#
#      Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 8 a.m. and 8:59 a.m.  \
# 162                                              475.0
#
#      Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 9 a.m. and 11:59 a.m.  \
# 162                                              250.0
#
#      Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 12 p.m. and 4:59 a.m.  \
# 162                                              185.0
#
#      Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Less than 15 minutes  \
# 162                                              180.0
#
#      Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / 15 to 29 minutes  \
# 162                                              550.0
#
#      ...  \
# 162  ...
#
#      Age & Sex - Females / Total - Age groups and average age of the population - 100% data ; Females / 15 to 64 years ; Females  \
# 162                                             1050.0
#
#      Age & Sex - Females / Total - Age groups and average age of the population - 100% data ; Females / 65 years and over ; Females  \
# 162                                              115.0
#
#      Age & Sex - Females / Average age of the population ; Females  \
# 162                                               37.1
#
#      Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 0 to 14 years ; Females  \
# 162                                               12.4
#
#      Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 15 to 64 years ; Females  \
# 162                                               78.7
#
#      Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 65 years and over ; Females  \
# 162                                                8.6
#
#      Population and dwelling counts / Population, 2016  \
# 162                                             2749.0
#
#      Population and dwelling counts / Total private dwellings  \
# 162                                             1670.0
#
#      Population and dwelling counts / Private dwellings occupied by usual residents  \
# 162                                             1519.0
#
#      Population and dwelling counts / Population density per square kilometre
# 162                                            16353.4
#
# [1 rows x 155 columns]

# %%
list(census_data.columns)
# Out:
# ['GEO UID',
#  'Census Tract name',
#  'Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 5 a.m. and 5:59 a.m.',
#  'Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 6 a.m. and 6:59 a.m.',
#  'Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 7 a.m. and 7:59 a.m.',
#  'Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 8 a.m. and 8:59 a.m.',
#  'Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 9 a.m. and 11:59 a.m.',
#  'Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 12 p.m. and 4:59 a.m.',
#  'Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Less than 15 minutes',
#  'Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / 15 to 29 minutes',
#  'Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / 30 to 44 minutes',
#  'Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / 45 to 59 minutes',
#  'Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / 60 minutes and over',
#  'Labour - Total Sex / Total - Population aged 15 years and over by Labour force status - 25% sample data / In the labour force',
#  'Labour - Total Sex / Total - Population aged 15 years and over by Labour force status - 25% sample data / In the labour force / Employed',
#  'Labour - Total Sex / Total - Population aged 15 years and over by Labour force status - 25% sample data / In the labour force / Unemployed',
#  'Labour - Total Sex / Total - Population aged 15 years and over by Labour force status - 25% sample data / Not in the labour force',
#  'Labour - Total Sex / Total - Place of work status for the employed labour force aged 15 years and over in private households - 25% sample data / Worked at home',
#  'Labour - Total Sex / Total - Place of work status for the employed labour force aged 15 years and over in private households - 25% sample data / Worked outside Canada',
#  'Labour - Total Sex / Total - Place of work status for the employed labour force aged 15 years and over in private households - 25% sample data / No fixed workplace address',
#  'Labour - Total Sex / Total - Place of work status for the employed labour force aged 15 years and over in private households - 25% sample data / Worked at usual place',
#  'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data / No certificate, diploma or degree',
#  'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data / Secondary (high) school diploma or equivalency certificate',
#  'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data / Postsecondary certificate, diploma or degree',
#  'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 25 to 64 years in private households - 25% sample data / No certificate, diploma or degree',
#  'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 25 to 64 years in private households - 25% sample data / Secondary (high) school diploma or equivalency certificate',
#  'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 25 to 64 years in private households - 25% sample data / Postsecondary certificate, diploma or degree',
#  'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 25 to 64 years in private households - 25% sample data / Postsecondary certificate, diploma or degree / Apprenticeship or trades certificate or diploma',
#  'Housing - Total Sex / Total - Private households by tenure - 25% sample data / Owner',
#  'Housing - Total Sex / Total - Private households by tenure - 25% sample data / Renter',
#  'Housing - Total Sex / Total - Private households by tenure - 25% sample data / Band housing',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of bedrooms - 25% sample data / No bedrooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of bedrooms - 25% sample data / 1 bedroom',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of bedrooms - 25% sample data / 2 bedrooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of bedrooms - 25% sample data / 3 bedrooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of bedrooms - 25% sample data / 4 or more bedrooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of rooms - 25% sample data / 1 to 4 rooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of rooms - 25% sample data / 5 rooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of rooms - 25% sample data / 6 rooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of rooms - 25% sample data / 7 rooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of rooms - 25% sample data / 8 or more rooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data / 1960 or before',
#  'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data / 1961 to 1980',
#  'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data / 1981 to 1990',
#  'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data / 1991 to 2000',
#  'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data / 2001 to 2005',
#  'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data / 2006 to 2010',
#  'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data / 2011 to 2016',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 15 to 24 years',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 25 to 34 years',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 35 to 44 years',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 45 to 54 years',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 55 to 64 years',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 65 to 74 years',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 75 to 84 years',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 85 years and over',
#  'Income - Total Sex / Total - Income statistics in 2015 for the population aged 15 years and over in private households - 100% data / Number of total income recipients aged 15 years and over in private households - 100% data / Median total income in 2015 among recipients ($)',
#  'Income - Total Sex / Total - Income statistics in 2015 for the population aged 15 years and over in private households - 100% data / Number of after-tax income recipients aged 15 years and over in private households - 100% data / Median after-tax income in 2015 among recipients ($)',
#  'Income - Total Sex / Total - Income statistics in 2015 for the population aged 15 years and over in private households - 100% data / Number of employment income recipients aged 15 years and over in private households - 100% data / Median employment income in 2015 among recipients ($)',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / Under $10,000 (including loss)',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $10,000 to $19,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $20,000 to $29,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $30,000 to $39,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $40,000 to $49,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $50,000 to $59,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $60,000 to $69,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $70,000 to $79,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $80,000 to $89,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $90,000 to $99,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $100,000 and over',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / Under $10,000 (including loss)',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $10,000 to $19,999',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $20,000 to $29,999',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $30,000 to $39,999',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $40,000 to $49,999',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $50,000 to $59,999',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $60,000 to $69,999',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $70,000 to $79,999',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $80,000 and over',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / Under $5,000 (including loss)',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $5,000 to $9,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $10,000 to $19,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $20,000 to $29,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $30,000 to $39,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $40,000 to $49,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $50,000 to $59,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $60,000 to $69,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $70,000 to $79,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $80,000 and over',
#  'Income - Total Sex / Total - Income statistics in 2015 for private households by household size - 100% data / Median total income of households in 2015 ($)',
#  'Income - Total Sex / Total - Income statistics in 2015 for private households by household size - 100% data / Median after-tax income of households in 2015 ($) / Total - Income statistics in 2015 for one-person private households - 100% data / Median total income of one-person households in 2015 ($)',
#  'Income - Total Sex / Total - Income statistics in 2015 for private households by household size - 100% data / Median after-tax income of households in 2015 ($) / Total - Income statistics in 2015 for one-person private households - 100% data / Median after-tax income of one-person households in 2015 ($)',
#  'Income - Total Sex / Total - Income statistics in 2015 for private households by household size - 100% data / Median after-tax income of households in 2015 ($) / Total - Income statistics in 2015 for two-or-more-person private households - 100% data / Median total income of two-or-more-person households in 2015 ($)',
#  'Income - Total Sex / Total - Income statistics in 2015 for private households by household size - 100% data / Median after-tax income of households in 2015 ($) / Total - Income statistics in 2015 for two-or-more-person private households - 100% data / Median after-tax income of two-or-more-person households in 2015 ($)',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / Under $5,000',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $5,000 to $9,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $10,000 to $14,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $15,000 to $19,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $20,000 to $24,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $25,000 to $29,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $30,000 to $34,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $35,000 to $39,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $40,000 to $44,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $45,000 to $49,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $50,000 to $59,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $60,000 to $69,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $70,000 to $79,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $80,000 to $89,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $90,000 to $99,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $100,000 and over',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / Under $5,000',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $5,000 to $9,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $10,000 to $14,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $15,000 to $19,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $20,000 to $24,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $25,000 to $29,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $30,000 to $34,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $35,000 to $39,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $40,000 to $44,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $45,000 to $49,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $50,000 to $59,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $60,000 to $69,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $70,000 to $79,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $80,000 to $89,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $90,000 to $99,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $100,000 and over',
#  'Dwelling characteristics / Total - Occupied private dwellings by structural type of dwelling - 100% data / Single-detached house',
#  'Dwelling characteristics / Total - Occupied private dwellings by structural type of dwelling - 100% data / Apartment in a building that has five or more storeys',
#  'Dwelling characteristics / Total - Occupied private dwellings by structural type of dwelling - 100% data / Other attached dwelling',
#  'Dwelling characteristics / Total - Occupied private dwellings by structural type of dwelling - 100% data / Movable dwelling',
#  'Dwelling characteristics / Total - Private households by household size - 100% data / 1 person',
#  'Dwelling characteristics / Total - Private households by household size - 100% data / 2 persons',
#  'Dwelling characteristics / Total - Private households by household size - 100% data / 3 persons',
#  'Dwelling characteristics / Total - Private households by household size - 100% data / 4 persons',
#  'Dwelling characteristics / Total - Private households by household size - 100% data / 5 or more persons',
#  'Dwelling characteristics / Average household size',
#  'Dwelling characteristics / Number of persons in private households',
#  'Age & Sex - Males / Total - Age groups and average age of the population - 100% data ; Males / 0 to 14 years ; Males',
#  'Age & Sex - Males / Total - Age groups and average age of the population - 100% data ; Males / 15 to 64 years ; Males',
#  'Age & Sex - Males / Total - Age groups and average age of the population - 100% data ; Males / 65 years and over ; Males',
#  'Age & Sex - Males / Average age of the population ; Males',
#  'Age & Sex - Males / Total - Distribution (%) of the population by broad age groups - 100% data ; Males / 0 to 14 years ; Males',
#  'Age & Sex - Males / Total - Distribution (%) of the population by broad age groups - 100% data ; Males / 15 to 64 years ; Males',
#  'Age & Sex - Males / Total - Distribution (%) of the population by broad age groups - 100% data ; Males / 65 years and over ; Males',
#  'Age & Sex - Females / Total - Age groups and average age of the population - 100% data ; Females / 0 to 14 years ; Females',
#  'Age & Sex - Females / Total - Age groups and average age of the population - 100% data ; Females / 15 to 64 years ; Females',
#  'Age & Sex - Females / Total - Age groups and average age of the population - 100% data ; Females / 65 years and over ; Females',
#  'Age & Sex - Females / Average age of the population ; Females',
#  'Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 0 to 14 years ; Females',
#  'Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 15 to 64 years ; Females',
#  'Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 65 years and over ; Females',
#  'Population and dwelling counts / Population, 2016',
#  'Population and dwelling counts / Total private dwellings',
#  'Population and dwelling counts / Private dwellings occupied by usual residents',
#  'Population and dwelling counts / Population density per square kilometre']

# %%
census_data.columns
# Out:
# Index(['GEO UID', 'CMA code', 'Census Tract name',
#        'Journey to Work - Total Sex / Total - Commuting destination for the employed labour force aged 15 years and over in private households with',
#        'Journey to Work - Total Sex / Total - Main mode of commuting for the employed labour force aged 15 years and over in private households wit',
#        'Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a',
#        'Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with',
#        'Labour - Total Sex / Total - Population aged 15 years and over by Labour force status - 25% sample data',
#        'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25',
#        'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 25 to 64 years in private households - 25% s',
#        'Housing - Total Sex / Total - Private households by tenure - 25% sample data',
#        'Housing - Total Sex / Total - Occupied private dwellings by condominium status - 25% sample data',
#        'Housing - Total Sex / Total - Occupied private dwellings by number of bedrooms - 25% sample data',
#        'Housing - Total Sex / Total - Occupied private dwellings by number of rooms - 25% sample data',
#        'Housing - Total Sex / Average number of rooms per dwelling',
#        'Housing - Total Sex / Total - Private households by number of persons per room - 25% sample data',
#        'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data',
#        'Housing - Total Sex / Total - Private households by number of household maintainers - 25% sample data',
#        'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data',
#        'Housing - Total Sex / Total -  Owner and tenant households with household total income greater than zero, in non-farm, non-reserve private',
#        'Housing - Total Sex / Total - Owner households in non-farm, non-reserve private dwellings - 25% sample data',
#        'Housing - Total Sex / Total - Tenant households in non-farm, non-reserve private dwellings - 25% sample data',
#        'Income - Total Sex / Total - Income statistics in 2015 for the population aged 15 years and over in private households - 100% data',
#        'Income - Total Sex / Composition of total income in 2015 of the population aged 15 years and over in private households (%) - 100% data',
#        'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data',
#        'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data',
#        'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data',
#        'Income - Total Sex / Total - Income statistics in 2015 for private households by household size - 100% data',
#        'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data',
#        'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data',
#        'Marital Status - Both Sexes / Total - Marital status for the population aged 15 years and over - 100% data ; Both sexes',
#        'Family characteristics / Total - Census families in private households by family size - 100% data',
#        'Households by type / Total - Private households by household type - 100% data',
#        'Dwelling characteristics / Total - Occupied private dwellings by structural type of dwelling - 100% data',
#        'Dwelling characteristics / Total - Private households by household size - 100% data',
#        'Dwelling characteristics / Average household size',
#        'Age & Sex - Both sexes / Total - Age groups and average age of the population - 100% data ; Both sexes',
#        'Age & Sex - Both sexes / Total - Distribution (%) of the population by broad age groups - 100% data ; Both sexes',
#        'Population and dwelling counts / Population, 2016',
#        'Population and dwelling counts / Total private dwellings',
#        'Population and dwelling counts / Private dwellings occupied by usual residents',
#        'Population and dwelling counts / Population density per square kilometre'],
#       dtype='object')

# %%
census_data=pd.read_excel("Montreal Tracts.xlsx")
census_data.head()
# Out:
#    GEO UID Census Tract name  \
# 0     COL0              COL1
# 1  4620000                 0
# 2  4620001                 1
# 3  4620002                 2
# 4  4620003                 3
#
#   Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 5 a.m. and 5:59 a.m.  \
# 0                                               COL2
# 1                                             144135
# 2                                                120
# 3                                                170
# 4                                                220
#
#   Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 6 a.m. and 6:59 a.m.  \
# 0                                               COL3
# 1                                             329230
# 2                                                280
# 3                                                280
# 4                                                605
#
#   Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 7 a.m. and 7:59 a.m.  \
# 0                                               COL4
# 1                                             528075
# 2                                                435
# 3                                                460
# 4                                                760
#
#   Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 8 a.m. and 8:59 a.m.  \
# 0                                               COL5
# 1                                             383810
# 2                                                190
# 3                                                230
# 4                                                460
#
#   Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 9 a.m. and 11:59 a.m.  \
# 0                                               COL6
# 1                                             217905
# 2                                                120
# 3                                                 95
# 4                                                235
#
#   Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 12 p.m. and 4:59 a.m.  \
# 0                                               COL7
# 1                                             280660
# 2                                                220
# 3                                                415
# 4                                                535
#
#   Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Less than 15 minutes  \
# 0                                               COL8
# 1                                             341880
# 2                                                220
# 3                                                255
# 4                                                385
#
#   Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / 15 to 29 minutes  \
# 0                                               COL9
# 1                                             601245
# 2                                                415
# 3                                                525
# 4                                                885
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Age & Sex - Females / Total - Age groups and average age of the population - 100% data ; Females / 15 to 64 years ; Females  \
# 0                                             COL145
# 1                                            1379570
# 2                                                945
# 3                                               1200
# 4                                               2210
#
#   Age & Sex - Females / Total - Age groups and average age of the population - 100% data ; Females / 65 years and over ; Females  \
# 0                                             COL146
# 1                                             380345
# 2                                                220
# 3                                                345
# 4                                                590
#
#   Age & Sex - Females / Average age of the population ; Females  \
# 0                                             COL147
# 1                                               41.6
# 2                                               43.4
# 3                                               42.2
# 4                                                 43
#
#   Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 0 to 14 years ; Females  \
# 0                                             COL148
# 1                                               16.1
# 2                                               10.4
# 3                                                 16
# 4                                               14.8
#
#   Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 15 to 64 years ; Females  \
# 0                                             COL149
# 1                                               65.8
# 2                                               72.7
# 3                                               65.2
# 4                                               67.4
#
#   Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 65 years and over ; Females  \
# 0                                             COL150
# 1                                               18.1
# 2                                               16.9
# 3                                               18.8
# 4                                                 18
#
#   Population and dwelling counts / Population, 2016  \
# 0                                            COL151
# 1                                           4098927
# 2                                              2638
# 3                                              3516
# 4                                              6373
#
#   Population and dwelling counts / Total private dwellings  \
# 0                                             COL152
# 1                                            1823281
# 2                                               1452
# 3                                               1902
# 4                                               3103
#
#   Population and dwelling counts / Private dwellings occupied by usual residents  \
# 0                                             COL153
# 1                                            1727310
# 2                                               1328
# 3                                               1762
# 4                                               2937
#
#   Population and dwelling counts / Population density per square kilometre
# 0                                             COL154
# 1                                              890.2
# 2                                               5710
# 3                                             9029.3
# 4                                             8612.2
#
# [5 rows x 155 columns]

# %%
display(list(census_data.columns))
# Out:
# ['GEO UID',
#  'Census Tract name',
#  'Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 5 a.m. and 5:59 a.m.',
#  'Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 6 a.m. and 6:59 a.m.',
#  'Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 7 a.m. and 7:59 a.m.',
#  'Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 8 a.m. and 8:59 a.m.',
#  'Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 9 a.m. and 11:59 a.m.',
#  'Journey to Work - Total Sex / Total - Time leaving for work for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Between 12 p.m. and 4:59 a.m.',
#  'Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / Less than 15 minutes',
#  'Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / 15 to 29 minutes',
#  'Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / 30 to 44 minutes',
#  'Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / 45 to 59 minutes',
#  'Journey to Work - Total Sex / Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data / 60 minutes and over',
#  'Labour - Total Sex / Total - Population aged 15 years and over by Labour force status - 25% sample data / In the labour force',
#  'Labour - Total Sex / Total - Population aged 15 years and over by Labour force status - 25% sample data / In the labour force / Employed',
#  'Labour - Total Sex / Total - Population aged 15 years and over by Labour force status - 25% sample data / In the labour force / Unemployed',
#  'Labour - Total Sex / Total - Population aged 15 years and over by Labour force status - 25% sample data / Not in the labour force',
#  'Labour - Total Sex / Total - Place of work status for the employed labour force aged 15 years and over in private households - 25% sample data / Worked at home',
#  'Labour - Total Sex / Total - Place of work status for the employed labour force aged 15 years and over in private households - 25% sample data / Worked outside Canada',
#  'Labour - Total Sex / Total - Place of work status for the employed labour force aged 15 years and over in private households - 25% sample data / No fixed workplace address',
#  'Labour - Total Sex / Total - Place of work status for the employed labour force aged 15 years and over in private households - 25% sample data / Worked at usual place',
#  'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data / No certificate, diploma or degree',
#  'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data / Secondary (high) school diploma or equivalency certificate',
#  'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data / Postsecondary certificate, diploma or degree',
#  'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 25 to 64 years in private households - 25% sample data / No certificate, diploma or degree',
#  'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 25 to 64 years in private households - 25% sample data / Secondary (high) school diploma or equivalency certificate',
#  'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 25 to 64 years in private households - 25% sample data / Postsecondary certificate, diploma or degree',
#  'Education - Total Sex / Total - Highest certificate, diploma or degree for the population aged 25 to 64 years in private households - 25% sample data / Postsecondary certificate, diploma or degree / Apprenticeship or trades certificate or diploma',
#  'Housing - Total Sex / Total - Private households by tenure - 25% sample data / Owner',
#  'Housing - Total Sex / Total - Private households by tenure - 25% sample data / Renter',
#  'Housing - Total Sex / Total - Private households by tenure - 25% sample data / Band housing',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of bedrooms - 25% sample data / No bedrooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of bedrooms - 25% sample data / 1 bedroom',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of bedrooms - 25% sample data / 2 bedrooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of bedrooms - 25% sample data / 3 bedrooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of bedrooms - 25% sample data / 4 or more bedrooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of rooms - 25% sample data / 1 to 4 rooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of rooms - 25% sample data / 5 rooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of rooms - 25% sample data / 6 rooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of rooms - 25% sample data / 7 rooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by number of rooms - 25% sample data / 8 or more rooms',
#  'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data / 1960 or before',
#  'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data / 1961 to 1980',
#  'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data / 1981 to 1990',
#  'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data / 1991 to 2000',
#  'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data / 2001 to 2005',
#  'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data / 2006 to 2010',
#  'Housing - Total Sex / Total - Occupied private dwellings by period of construction - 25% sample data / 2011 to 2016',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 15 to 24 years',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 25 to 34 years',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 35 to 44 years',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 45 to 54 years',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 55 to 64 years',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 65 to 74 years',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 75 to 84 years',
#  'Housing - Total Sex / Total - Private households by age of primary household maintainers - 25% sample data / 85 years and over',
#  'Income - Total Sex / Total - Income statistics in 2015 for the population aged 15 years and over in private households - 100% data / Number of total income recipients aged 15 years and over in private households - 100% data / Median total income in 2015 among recipients ($)',
#  'Income - Total Sex / Total - Income statistics in 2015 for the population aged 15 years and over in private households - 100% data / Number of after-tax income recipients aged 15 years and over in private households - 100% data / Median after-tax income in 2015 among recipients ($)',
#  'Income - Total Sex / Total - Income statistics in 2015 for the population aged 15 years and over in private households - 100% data / Number of employment income recipients aged 15 years and over in private households - 100% data / Median employment income in 2015 among recipients ($)',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / Under $10,000 (including loss)',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $10,000 to $19,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $20,000 to $29,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $30,000 to $39,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $40,000 to $49,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $50,000 to $59,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $60,000 to $69,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $70,000 to $79,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $80,000 to $89,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $90,000 to $99,999',
#  'Income - Total Sex / Total - Total income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with total income / $100,000 and over',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / Under $10,000 (including loss)',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $10,000 to $19,999',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $20,000 to $29,999',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $30,000 to $39,999',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $40,000 to $49,999',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $50,000 to $59,999',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $60,000 to $69,999',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $70,000 to $79,999',
#  'Income - Total Sex / Total - After-tax income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with after-tax income / $80,000 and over',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / Under $5,000 (including loss)',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $5,000 to $9,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $10,000 to $19,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $20,000 to $29,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $30,000 to $39,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $40,000 to $49,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $50,000 to $59,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $60,000 to $69,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $70,000 to $79,999',
#  'Income - Total Sex / Total - Employment income groups in 2015 for the population aged 15 years and over in private households - 100% data / Percentage with employment income / $80,000 and over',
#  'Income - Total Sex / Total - Income statistics in 2015 for private households by household size - 100% data / Median total income of households in 2015 ($)',
#  'Income - Total Sex / Total - Income statistics in 2015 for private households by household size - 100% data / Median after-tax income of households in 2015 ($) / Total - Income statistics in 2015 for one-person private households - 100% data / Median total income of one-person households in 2015 ($)',
#  'Income - Total Sex / Total - Income statistics in 2015 for private households by household size - 100% data / Median after-tax income of households in 2015 ($) / Total - Income statistics in 2015 for one-person private households - 100% data / Median after-tax income of one-person households in 2015 ($)',
#  'Income - Total Sex / Total - Income statistics in 2015 for private households by household size - 100% data / Median after-tax income of households in 2015 ($) / Total - Income statistics in 2015 for two-or-more-person private households - 100% data / Median total income of two-or-more-person households in 2015 ($)',
#  'Income - Total Sex / Total - Income statistics in 2015 for private households by household size - 100% data / Median after-tax income of households in 2015 ($) / Total - Income statistics in 2015 for two-or-more-person private households - 100% data / Median after-tax income of two-or-more-person households in 2015 ($)',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / Under $5,000',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $5,000 to $9,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $10,000 to $14,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $15,000 to $19,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $20,000 to $24,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $25,000 to $29,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $30,000 to $34,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $35,000 to $39,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $40,000 to $44,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $45,000 to $49,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $50,000 to $59,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $60,000 to $69,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $70,000 to $79,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $80,000 to $89,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $90,000 to $99,999',
#  'Income - Total Sex / Total - Household total income groups in 2015 for private households - 100% data / $100,000 and over',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / Under $5,000',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $5,000 to $9,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $10,000 to $14,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $15,000 to $19,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $20,000 to $24,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $25,000 to $29,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $30,000 to $34,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $35,000 to $39,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $40,000 to $44,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $45,000 to $49,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $50,000 to $59,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $60,000 to $69,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $70,000 to $79,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $80,000 to $89,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $90,000 to $99,999',
#  'Income - Total Sex / Total - Household after-tax income groups in 2015 for private households - 100% data / $100,000 and over',
#  'Dwelling characteristics / Total - Occupied private dwellings by structural type of dwelling - 100% data / Single-detached house',
#  'Dwelling characteristics / Total - Occupied private dwellings by structural type of dwelling - 100% data / Apartment in a building that has five or more storeys',
#  'Dwelling characteristics / Total - Occupied private dwellings by structural type of dwelling - 100% data / Other attached dwelling',
#  'Dwelling characteristics / Total - Occupied private dwellings by structural type of dwelling - 100% data / Movable dwelling',
#  'Dwelling characteristics / Total - Private households by household size - 100% data / 1 person',
#  'Dwelling characteristics / Total - Private households by household size - 100% data / 2 persons',
#  'Dwelling characteristics / Total - Private households by household size - 100% data / 3 persons',
#  'Dwelling characteristics / Total - Private households by household size - 100% data / 4 persons',
#  'Dwelling characteristics / Total - Private households by household size - 100% data / 5 or more persons',
#  'Dwelling characteristics / Average household size',
#  'Dwelling characteristics / Number of persons in private households',
#  'Age & Sex - Males / Total - Age groups and average age of the population - 100% data ; Males / 0 to 14 years ; Males',
#  'Age & Sex - Males / Total - Age groups and average age of the population - 100% data ; Males / 15 to 64 years ; Males',
#  'Age & Sex - Males / Total - Age groups and average age of the population - 100% data ; Males / 65 years and over ; Males',
#  'Age & Sex - Males / Average age of the population ; Males',
#  'Age & Sex - Males / Total - Distribution (%) of the population by broad age groups - 100% data ; Males / 0 to 14 years ; Males',
#  'Age & Sex - Males / Total - Distribution (%) of the population by broad age groups - 100% data ; Males / 15 to 64 years ; Males',
#  'Age & Sex - Males / Total - Distribution (%) of the population by broad age groups - 100% data ; Males / 65 years and over ; Males',
#  'Age & Sex - Females / Total - Age groups and average age of the population - 100% data ; Females / 0 to 14 years ; Females',
#  'Age & Sex - Females / Total - Age groups and average age of the population - 100% data ; Females / 15 to 64 years ; Females',
#  'Age & Sex - Females / Total - Age groups and average age of the population - 100% data ; Females / 65 years and over ; Females',
#  'Age & Sex - Females / Average age of the population ; Females',
#  'Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 0 to 14 years ; Females',
#  'Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 15 to 64 years ; Females',
#  'Age & Sex - Females / Total - Distribution (%) of the population by broad age groups - 100% data ; Females / 65 years and over ; Females',
#  'Population and dwelling counts / Population, 2016',
#  'Population and dwelling counts / Total private dwellings',
#  'Population and dwelling counts / Private dwellings occupied by usual residents',
#  'Population and dwelling counts / Population density per square kilometre']

# %%
our_tract=census_data[census_data["Census Tract name"]==147]

# %%
import plotly.express as px

# %%
our_tract['Dwelling characteristics / Total - Private households by household size - 100% data / 1 person']
# Out:
# 163    760
# Name: Dwelling characteristics / Total - Private households by household size - 100% data / 1 person, dtype: object

# %%
our_tract['Population and dwelling counts / Population, 2016']
# Out:
# 163    2749
# Name: Population and dwelling counts / Population, 2016, dtype: object

# %%
our_tract['Population and dwelling counts / Total private dwellings']
# Out:
# 163    1670
# Name: Population and dwelling counts / Total private dwellings, dtype: object
